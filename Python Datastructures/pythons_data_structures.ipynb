# %% [markdown]
# # Pythons Data Structures

# %%
list = [1, 2, 3, 4, 5]
tuple = (1, 2, 2, 2, 3, 4, 2)
set = {1, 2, 3, 4, 5}
dict = {1: 'one', 2: 'two', 3: 'three', 4: 'four', 5: 'five'}

print("List Example")
# insert using insert, append, or direct access
print(list)
list[0] = 6
print(list)
list.insert(0, 1)
print(list)
list.append(6)

# remove using remove, pop, or del
print(list)
list.remove(6)
print(list)
list.pop()
print(list)
list.pop(2)
print(list)
del list[1]
print(list)


# Range in lists
print("Range in lists")
print(list)
newList = my_list(range(1, 10))
print(newList)

print("\nTuple Example")
# Accessing elements
print(tuple)
print(tuple[0])
print(tuple[1:3])

# Built in functions
print("count: ", tuple.count(2))
print("Index: ",tuple.index(2))

#Immutability
# tuple[0] = 6 # This will throw an error
new_tuple = (6, 7, 8, 9, 10)
# Concat a new tuple
print(tuple + new_tuple)


print("\nSet Example")

# Adding elements
print(set)
set.add(6)
print(set)

# Adding multiple elements using update
set.update([7, 8, 9])
print(set)

# Removing elements
set.remove(6)
print(set)
set.remove(7)
print(set)

# Unique elements
set.update([8, 8, 8])
print(set)


print("\nDictionary Example")
# Accessing elements
print(dict)
print(dict[1])
print(dict.keys())

# Adding elements
dict[6] = 'six'
print(dict)

# Adding multiple elements using update
dict.update({7: 'seven', 8: 'eight'})
print(dict)


# Removing elements
del dict[6]
print(dict)
dict.pop(7)
print(dict)

# built in functions

# clear
dict.clear()
print(dict)

# copy
dict = {1: 'one', 2: 'two', 3: 'three', 4: 'four', 5: 'five'}
dict_copy = dict.copy()
print(dict_copy)

# fromkeys
dict = dict.fromkeys([1, 2, 3, 4, 5], 'default')
print(dict)
# Out:
# List Example
# [1, 2, 3, 4, 5]
# [6, 2, 3, 4, 5]
# [1, 6, 2, 3, 4, 5]
# [1, 6, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5]
# [1, 2, 4, 5]
# [1, 4, 5]
# Range in lists
# [1, 4, 5]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 31
#      29 print(list)
#      30 my_list = []
# ---> 31 newList = my_list(range(1, 10))
#      32 print(newList)
#      34 print("\nTuple Example")
#
# TypeError: 'list' object is not callable
